# %%
**1.Explain the key features of Python that make it a popular choice for programming.**

Python is interpreted high level programming language. Python was developed by Guido van Rossum and was first launched in 1991. It is beginner and developer friendly in nature due to its features. 
The features of Python are given below:

**a) Easy to Learn**
     Everyone can learn Python, because it is not necessary to know any base language, such as C, beforehand. The syntex of Python is very easy as it eliminates the requirement for writing library files, main functions and other functions; we only need to write what we need. Moreover we do not need to declare datatype for a variable. Due to its huge number of libraries developers can more focus on solving problems rather then tangled in language specifics.
     For Example: 
                     print("This is my first assignment")

We only need to write one line of code in order to print one line. However, we must write at least 7-8 lines of code in other languages.
This makes Python easy to learn.

**b) Vast Libraries**
     Python has variety of in built libraries that can be used by many different fields.

     For example: SciPy, Matplotlib libraries are used to do Scientific computing.
                  Data science and machine learning can also be done using libraries like Pandas, NumPy, TensorFlow, and PyTorch.
                  Game development can be done using libraries like Pygame.
                  Python can even communicate with Arduino using pySerial, pyFirmata, arduino-cli and ino libraries.

**c) Versatility and Wide Application**
     Python is really a versatile language because Python has easy syntax anyone can learn easily and its libraries make it wide application.
     From basic coding to AI, ML and NLP can be done using Python. many fields are covered in Python. 

**d)  Data Science and Machine Learning**
      Python's ability to process and analyze data makes it the most popular language for data research.
      We utilize libraries like Pandas, NumPy, SciPy, Matplotlib, and Seaborn to execute out data science operations.
      The libraries mentioned above are used for:   Data exploration and Data Analysis.
                                                    Testing hypotheses and statistical models.
                                                    Making visual representations of data.
                                                    Utilizing extensive data pipelines and databases.
      These libraries are used in the domains of finance, healthcare, marketing, and research.

      For instance, using Matplotlib to create charts and plots and Pandas to manage and analyze huge datasets.

**e) Extensive Tooling and Automation**
     Python can automaticall generate reports, documents and PDFs using ReportLab, Jinja2, XlxsWriter libraries. 
     Moreover it can generate dynamic HTML sheets automatically. Due to this reason Python is widely used for tooling and Automation. 
     

**f) Community and Support**
     Among all other languages Python has strong and huge community support.
     Many developers are fixing bugs and updating tools in Python on daily basis.
     Python is famous because it is conducting many conferences and local meetups to build network, code and learn.

# %% [markdown]
# 2. Describe the role of predefined keywords in Python and provide examples of how they are used in a program.
#
#     Keywords are predefined in Python. They have some special roles for specific tasks. There are total 33 Keyboards in Python. They are also called as reserve words. They can't be used as identifiers for variable names, function names and many other user defined entities in a program.
#
#     Keywords in Python are
#     False, class, finally, is, return, None, continue, for, lambda, try, True, def, from, nonlocal, while, and, del, global, not, with, as, elif, if, or, yield, assert, else, import, pass, break, except, in raise.
#
#
#    Roles of predefined keywords in Python are given below:
#
#    **Control flow:**
#    Python have some control flow keywords that manage the flow of execution in a program which means they take decisions from start of the program to end of the program whether the condition falls on first command to last. The keywords used in control flow are if, else, elif, for, while, break, and continue.
#
#     For Example:
#     number = int(input("Enter a number: "))
#     factorial= 1
#     if number < 0:
#     print("Factorial doesnot exist for negative numbers")
#     elif number == 0:
#         print("The factorial of 0 is 1")
#     else:
#         for i in range(1, number+1):
#         factorial = factorial*i
#     print ("The factorial of a number is: " factorial)
#
#     **Function Definition:**
#     We can define functions in Python using keywords and we can also get return values from them. Function defining keywords are def, return, yield and lambda.
#    For Example:
#    def add_numbers(a,b):
#        return a+b
#    result = add_numbers(5,8)
#    print(result)
#
#
#     **OOPs:**
#     Python uses Object Oriented Programming concept. We can create classes and objects easily with real world entities. So, we can say everything in  Python is an object. Keywords like class, self, __init__ and square are related to objects and classes.
#
#     **Exception Handling:**
#     While executing a program, sometimes an unexpected error occurs (Like dividing anumber by zero) and we call it an exception.
#                             Keywords for handling these exceptions are try, expect, finally, raise and assert.
#
#     **Boolean Operations:**
#     In Python we can compare operations weather the condition is true or false using boolean logics (True/False). We use some keyboards like AND, OR, NOT, True, False and None for conditions.
#
#      **Context Management:**
#      Context mangagers basically work with resources. It manages files and network connection so that it can look them efficiently. Whether error occurs or any exception occurs it allocates the resources well. We an perform context management with teh help of with and as keywords.
#
#      **Importing Modules:**
#      Modules are in which python functions, classes etc are being imported. So that it can be reused repeatedly in the same or another python program.       We can Import modules with the help of Import, math and from keywords.d     in Importing     modules.
# F    or Example:
# import mat    h
# result = math.sqrt(16)
# print(result)

# %% [markdown]
# 3. Compare and contrast mutable and immutable obects in Python with examples.
#
#    **Mutable**
#     Mutable objects are those objects that user can change their values after they are created which means they are flexible to update.
#
#     For Example: Lists and Dictionaries
#
#     Lists: List is a Hetrogeneous collection of data which means we can create with more than two data types.
#     For Example:
#     my_list = [1, 2, 3, 4, 5]
#     empty_list = []
#     mixed_list = [1, "hello", 3.14, True]
#
#    # Suppose in mixed_list if we want to change true with false then we can change as below:
#
#     mixed_list[3]= "False"
#
#     **Immutable**
#     Mutable objects are those objects that user cannot change their values after they are created which means they are not flexible to update.
#     Forexample:
#     Integers, Foats, Strings etc.
#
#     a= "Akash"
#     a[1]="a"
#    It will show error because Strings are immutable.

# %% [markdown]
# 4. Discuss the different types of operators in Python and provide examples of how they are used.
#    **Operators**
#
#    Special keyword /symbols that are used to perform operations on operands are known as Operators.
#    There re 7 Operators in Python:
#    Arithmatic Operators
#    Comparison Operators
#    Logical Operators
#    Bitwise Operators
#    Assignment Operators
#    Membership Operators
#    Identity Operators
#
#    **Arithmetic Operators:**
#    These are used to make basic mathematics operations like addition(+), substraction(-), Divide(/), Modulus(%), Multiplication(*), Floor(//) and Power(**).
#
#    For example:
#    a=5
#    b=10
#    c=a+b
#    d=a-b
#    e=a*b
#    f=a/b
#    g=a%b
#    h=a**b
#    i=a//b
#
#    **Comparison Operator**
#    Comparison Operators are used to compare two operands. We can perform equal to(==), not equal to(!=), greater than equal to(>=), less than equal to(<=), greater than(>), less than(<) operations. If the conditions matches then it will return True value other wise it will return False value.
#
#       For Example:
#    a=4
#    b=7
#    a==b
#    a!=b
#    a>=b
#    b<=b
#    a>b
#    a<b
#
#    **Logical Operator**
#    In these Operators we have three conditions AND, OR, NOT
#
#    AND means both the operands either should be true or false, then only the condition will become true.
#    For Example:
#    a=5
#    b=7
#    print(a>0 and b>0)
#    print(a<0 and b>0)
#
#    OR means only one operand should be true.
#    For Example
#    a=5
#    b=7
#    c=-8
#    d=((a>0 and b>0) or (d>0)
#    print(d)
#
#    NOT means opposite to operand. Suppose if the value of a is true then it will make it false.
#    a=5
#    b=7
#    d= not(a>0 and b>0)
#
#    **Assignment Operator**
#    These operators are used to assign values to variables.
#    We have:
#     = assign value on right side to left variable.
#     += adds the right operand to the left operand and then assign the value to left side.
#     -= Subtract the right operand to the left operand and then assign the value to left side.
#     *= Multiply the right operand to the left operand and then assign the value to left side.
#     /= Divide the right operand to the left operand and then assign the value to left side.
#     >= Assign value is greater than or equal to
#     <= Assign value is greater than or equal to
#
#     For Example:
#     x=4
#     x*=4
#
#    **Bitwise Operator**
#    It performs operations at bit level, manipulating individuals bits with integers.
#    &, |, ~, ^ are Bitwise Operators.
#
#     For Example:
#    AND(&)
#    10 & 10
#    Binary of 10= 1010
#    Applying & operator on 1010 & 1010= 1010
#    In binary answer is 1010.
#
#    OR(|)
#    3|5
#    Binary of 3 is      0010
#    Binary of 5 is      0101
#    Puttin OR operator= 0111
#    And In numeric of this binary is 7.
#
#    Negation (~)
#    ~3
#    Output: -4 because it will go one lower value with (-) minus symbol.
#
#    XOR(^)
#    5^3
#    Binary Value of 5 is 101
#    Binary Value of 3 is 011
#    Implementing XOR   = 110
#    Binaryof 110 is 6
#
#    **Membership Operator**
#    It checks whether the value is present in the given value (variable, string, list, tuple or dictionary etc.) or not.
#    we have two membership operators.
#    in
#    not in
#
#    For Example
#    in
#    It wil give true result if the given value is present.
#    a= "AKASH"
#    "AS" in a
#    True
#
#    not in
#    a= "AKASH"
#    "SH" not in a
#    False
#
#
#    Identity Operator
#    It compare the location of two objects/variables. It checks whether the given variables hold same memory.
#
#    For Example:
#    a=2
#    b=3
#    a is b
#    False
#    a is not b
#    True

# %% [markdown]
# 5. Explain the concept of type casting in Python with examples.
#
#    It is a concept of converting one data type to another.
#    For Example: Converting Integer  to String
#
#    Ther are two types of type casting:
#    Implicit
#    Explicit
#
#    **Implicit Type Casting:**
#    When the systen declares the data type on it's own, implicit type conversion occurs.
#    For Example:
#    a=5
#    type(a)
#    Output: int
#
#    a= "Akash"
#    type(a)
#    Output: str
#
#    a="15"
#    type(a)
#    Output: str #system converts the int into str
#
#    **Explicit Type Casting**
#
#    When the user converts the type of data type explicitly.
#    For Example:
#     **Converting Float into Integer**
#     a= 3.4
#    type(a)
#    Output: float
#    int(a)
#    Output: 3 #the data type is explicitly changed
#
#     **Converting Integer into float**
#    a=2
#    type(a)
#    Output: int
#
#    b= float(a) #Converting integer into float.
#    b
#    Output: 2.0
#
#    **String to Float**
#    a= "2.3"
#    type(a)
#    Output: str
#    b=float(a)
#    type(b)
#    Output: float
#
#    **Integers to String**
#    a= 5
#    type(a)
#    Output: int
#    str(a)
#    Output: '5'
#    c= str(a)
#    type(c)

# %% [markdown]
# 6. How do conditional statements work in Python? Illustrate with examples.
#
#    Conditional statements helps us to code decisions based on some preconditions.
#    There are four conditional statements:
#    if
#    if-else
#    if-elif
#    nested if-else
#
#    **if statements**:
#    Here we set condition on which code will take decision.
#    Syntax:
#    if condition:
#        Block of code
#
#    For Example:
#        weather= "Rainy"
#        if weather== "Rainy"
#            print("I will not play cricket")
#
#    # We can write multiple conditions in if statement.
#    For Example:
#    number==42
#    if ((number%2==0)&(number>0)):
#        print("This is number")
#
#    **if else statements**
#     if else condition occurs when there is false statement in if block. If the block of code from if condition got false condition the else block will run.
#
#     For Example:
#    weather= "Sunny
#    if weather== "Rainy"
#            print("I will watch TV")
#     else:
#         print("I will play Cricket")
#
#    **elif statements**
#    We can set multiple conditions between if else using elif statements.
#
#    For example:
#    Score= 80
#    if score>=90:
#        print("Grade A+")
#    elif(80<= score<90)"
#        print("Grade B")
#    elif(70= score<80)"
#        print("Grade C")
#     else:
#        print("Grade D")
#
#    **Nested if else**
#    In nested if else statements we can have multiple if else inside if else statements.
#    x=1
#    y=6
#    if x>5:
#        if y>5:
#            print("Both x and are greater than 5")
#        else:
#            print("x and greater than 5 but y is less than 5")
#    else:
#        print("x is not greater than 5")

# %% [markdown]
# 7. Describe the different types of loops in Python and their use cases with examples.
#    Loop statements allow to execute a block of code repeatedly untill a certain conditon is met.
#    We can further explain loops in following types:
#    While Loop
#    While loop with else
#    For loop
#    For loop with else
#
#    **While Loop**
#    While loop executed a block of code as long as a condition is true.
#    While is a Python keyword used for a loop.
#
#    Syntax:
#    While Condition:
#    Block of Code
#
#    For Example:
#    count=5
#    while count>0
#        print(count)
#        count= count-1
#
#    **While Else**
#    n=7
#    i=1
#    while i<n:
#        print(i)
#        i=i+1
#        if i==3:
#        break
#    else:
#        print("This is else block")
#
#      **For Loop**
#        For loop is applied when we know the count of iterations through a sequence (like list, string, tuple or range).
#
#        For Example:
#        for i in range(4):
#            for j in range(i+1):
#            print("*", end="")
#        print()
#
#
#        **For Else**
#        l= [3.27, 25, "a+2b", "xyz"]
#        for i in l
#        if i== "a+2b"
#            continue
#            print(i)
#        else:
#            print("This is else block")
